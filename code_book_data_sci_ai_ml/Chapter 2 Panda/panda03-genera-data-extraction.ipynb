# %%
# ws13

import pandas as pd
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)
# df = pd.read_excel(uri, skiprows=[1,3])

df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)
df = pd.read_excel(uri, index_col='Name')
# df
df.head()
# df.tail()
# Out:
#          Age  Score  Section
# Name
# Kobkiat   25     35        1
# ณิแนน     22     26        1
# จอห์น     25     32        2
# Tim       35     29        2
# Steal     32     27        1

# %%
# ws14 sheet name and skip header and use columns
uri = 'data/score_ageb w header.xlsx'
cols = 'a,c:d'
cols = [0,2,3]
# df = pd.read_excel( )

df = pd.read_excel(uri, sheet_name='MySheet1', usecols=cols, header=3,
                  index_col='Name')
df.head()

# df.loc['Tim']
# df.loc['Tim']['Score']
# df.loc['Tim']['Section']
# df.sort_index()
# Out:
#          Score  Section
# Name
# Kobkiat     35        1
# ณิแนน       26        1
# จอห์น       32        2
# Tim         29        2
# Steal       27        1

# %%
# ws15
uri = 'data/score_ageb.xlsx'
mycolumns = ['Student','Math','Comp','Year']   # must match the number of columns

# df = pd.read_excel(uri, index_col='Student', names=mycolumns) # ok
df = pd.read_excel(uri, names=mycolumns, index_col='Student')  # ok
# df
# df.head()
df.Comp
df['Comp']
df.Comp['Kobkiat']
df['Comp']['Kobkiat']
df.Math['ณิแนน']
# Out:
# 22

# %%
# ws16
uri = 'data/score_ageb no column.xlsx'
mycolumns = ['Student','Math','Comp','Sec'] 
df = pd.read_excel(uri, header=None, names=mycolumns) # 
df.head()
# Out:
#    Student  Math  Comp  Sec
# 0  Kobkiat    25    35    1
# 1    ณิแนน    22    26    1
# 2    จอห์น    25    32    2
# 3      Tim    35    29    2
# 4    Steal    32    27    1

# %%
# ws17
uri = 'data/score_ageb.csv'

df = pd.read_csv(uri)
df = pd.read_csv(uri, encoding='utf-8')
df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
uri = 'data/score_ageb.csv'

df = pd.read_csv(uri, index_col='Name')
df.head()
# Out:
#          Age  Score  Section
# Name
# Kobkiat   25     35        1
# ณิแนน     22     26        1
# จอห์น     25     32        2
# Tim       35     29        2
# Steal     32     27        1

# %%
# ws18
uri = 'data/score_ageb.csv'

cols = ['Name','Score']
# cols = [0,2]  # first column =0

df = pd.read_csv(uri, usecols=cols) 
df.head()
# Out:
#       Name  Score
# 0  Kobkiat     35
# 1    ณิแนน     26
# 2    จอห์น     32
# 3      Tim     29
# 4    Steal     27

# %%
# ws18
uri = 'data/score_ageb.csv'

cols = ['Name','Score']
# cols = [0,2]  # first column =0

df = pd.read_csv(uri, usecols=cols,  nrows=4, skiprows=[1,2])
df.head()
# Out:
#     Name  Score
# 0  จอห์น     32
# 1    Tim     29
# 2  Steal     27
# 3   Mark     30

# %%
# ws19 csv no column
import pandas as pd

uri = 'data/score_ageb no column.csv'
columns = ['Student','Math','Comp','Year']
df = pd.read_csv(uri, names=columns, index_col='Student')
# df = pd.read_csv(uri)

df.head()
# Out:
#          Math  Comp  Year
# Student
# Kobkiat    25    35     1
# ณิแนน      22    26     1
# จอห์น      25    32     2
# Tim        35    29     2
# Steal      32    27     1

# %%
# ws20
uri = 'data/score_ageb.csv'
df = pd.read_csv(uri)
df.head()

# df.tail()
# df.sample(4)
# mydf = df.sample(5).copy()
# mydf

# df.describe()

# df.shape
# df.index
# df.columns
# df.values
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
df.dtypes
# Out:
# Name       object
# Age         int64
# Score       int64
# Section     int64
# dtype: object

# %%
# ws22
df.describe()
# df.Score.mean()
# df.Score.max()
# df.Score.min()
# df.Score.count()
# df.Score.std()
# Out:
#              Age      Score    Section
# count  10.000000  10.000000  10.000000
# mean   26.900000  29.700000   1.500000
# std     4.012481   3.465705   0.527046
# min    22.000000  25.000000   1.000000
# 25%    25.000000  27.250000   1.000000
# 50%    25.500000  29.500000   1.500000
# 75%    28.000000  31.500000   2.000000
# max    35.000000  35.000000   2.000000

# %%
# ws23
uri = 'data/score_ageb.csv'
df = pd.read_csv(uri, dtype={'Section':str})
df.dtypes
# Out:
# Name       object
# Age         int64
# Score       int64
# Section    object
# dtype: object

# %%
df.describe()
# Out:
#              Age      Score
# count  10.000000  10.000000
# mean   26.900000  29.700000
# std     4.012481   3.465705
# min    22.000000  25.000000
# 25%    25.000000  27.250000
# 50%    25.500000  29.500000
# 75%    28.000000  31.500000
# max    35.000000  35.000000

# %%
# ws23b
uri = 'data/score_ageb.csv'
df = pd.read_csv(uri)
df.Section = df.Section.astype('category')
df.dtypes
# df.describe()
# Out:
# Name         object
# Age           int64
# Score         int64
# Section    category
# dtype: object

# %%
# ws24 
uri = 'data/score_ageb.csv'
df = pd.read_csv(uri)
df.Name
# df.Score
# df['Name']
# df['Score']
# df.Name[1]
# df.Name[2:5]
# Out:
# 0    Kobkiat
# 1      ณิแนน
# 2      จอห์น
# 3        Tim
# 4      Steal
# 5       Mark
# 6        แดง
# 7         ดำ
# 8        ขาว
# 9        Bob
# Name: Name, dtype: object

# %%
# ws25
# df[1]  # not work
df[:]
df[1:4]
# df[1:4].Name
# Out:
#     Name  Age  Score  Section
# 1  ณิแนน   22     26        1
# 2  จอห์น   25     32        2
# 3    Tim   35     29        2

# %%
df.iloc[2]
df.iloc[2]['Name']
df.iloc[2,0] # same as ['Name']
df.iloc[1:4]
# Out:
#     Name  Age  Score  Section
# 1  ณิแนน   22     26        1
# 2  จอห์น   25     32        2
# 3    Tim   35     29        2

# %%
rows = [0,1,4]
df.iloc[rows]
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     26        1
# 4    Steal   32     27        1

# %%
# ws25 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri, index_col='Name')
df.iloc[2] # 

type(df.iloc[2])
# df
# df.loc['Tim']  # 
df.loc['Tim']['Age']
# df
# Out:
# 35

# %%
# ws26 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)

df[df.Name.str.match('Kob')]
df[df.Name.str.match('kob')]
df[df.Name.str.match('kob', case=False)]
# df[df.Name.str.match('kob', case=True)]

# df[df['Name'].str.match('Kob')]
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1

# %%
# ws25
df[df.Name.str.contains('kiat')]

# df[df.Name.str.contains('kiat')]['Age']
df[df.Name.str.contains('kiat')]['Age'][0]
# Out:
# 25

# %%
# ws27 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)

for idx, row in df.iterrows():
    print(idx, row.Name, row.Score)

# df
# Out:
# 0 Kobkiat 35
# 1 ณิแนน 26
# 2 จอห์น 32
# 3 Tim 29
# 4 Steal 27
# 5 Mark 30
# 6 แดง 35
# 7 ดำ 25
# 8 ขาว 28
# 9 Bob 30

# %%
# ws28a 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)
# df = df[df['Section'] == 2] 
# df[df.Section == 2] 
df = df[df.Score >= 30]
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 2    จอห์น   25     32        2
# 5     Mark   28     30        2
# 6      แดง   23     35        1
# 9      Bob   28     30        2

# %%
# ws28b 
df.loc[(df.Score >=30) & (df.Section == 2)]
# Out:
#     Name  Age  Score  Section
# 2  จอห์น   25     32        2
# 5   Mark   28     30        2
# 9    Bob   28     30        2

# %%
# ws28c
df.loc[(df.Score >=30) | (df.Section == 2)]
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 2    จอห์น   25     32        2
# 5     Mark   28     30        2
# 6      แดง   23     35        1
# 9      Bob   28     30        2

# %%
df.loc[(df.Age.isin([22]))]
df.loc[(df.Age.isin([22, 23, 28]))]
df.loc[(df.Age.isin([22, 23, 25])) & (df.Section == 1)]
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 6      แดง   23     35        1

# %%
# ws28
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)
# print(df)

df = df[df.Score >= 30] 
# df

for idx, row in df.iterrows():
#     print(idx, row.Name, row.Score, row.Section)
    if row.Section == 2:
#         print(idx, row.Name, row.Score, row.Section)
        print('{:2} {:8} {:4} {:3}'.format(idx, row.Name, 
                         row.Score, row.Section))
# Out:
#  2 จอห์น      32   2
#  5 Mark       30   2
#  9 Bob        30   2

# %%
# ws29 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri, index_col='Name')
df.sort_index(inplace=True)
# df = df.sort_index(ascending=False)
df.sort_values('Score')
df.sort_values('Score', ascending=False, inplace=True)

a = df.sort_values(['Section','Score'])
a
# Out:
#          Age  Score  Section
# Name
# ณิแนน     22     26        1
# Steal     32     27        1
# ขาว       25     28        1
# Kobkiat   25     35        1
# แดง       23     35        1
# ดำ        26     25        2
# Tim       35     29        2
# Bob       28     30        2
# Mark      28     30        2
# จอห์น     25     32        2

# %%
# ws30

uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)

df.at[1,'Score'] = 38
df.iat[1,2] = 34

df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     34        1
# 2    จอห์น   25     32        2
# 3      Tim   35     29        2
# 4    Steal   32     27        1

# %%
# ws31 
df.replace(2,8)
# df = df.replace(2,8)
df.replace(2,8, inplace=True)
# df = df.replace(8,2)
df.Section.replace(2,8, inplace=True)
df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 1    ณิแนน   22     34        1
# 2    จอห์น   25     32        8
# 3      Tim   35     29        8
# 4    Steal   32     27        1

# %%
# ws32
df.loc[df.Name.str.match('Kob'), 'Section'] = 5 # 
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        5
# 1    ณิแนน   22     34        1
# 2    จอห์น   25     32        8
# 3      Tim   35     29        8
# 4    Steal   32     27        1
# 5     Mark   28     30        8
# 6      แดง   23     35        1
# 7       ดำ   26     25        8
# 8      ขาว   25     28        1
# 9      Bob   28     30        8

# %%
# ws31 
df['Midterm'] = df['Score'] * 0.5
df['M'] = df['Age']
df.head()
# Out:
#       Name  Age  Score  Section  Midterm   M
# 0  Kobkiat   25     35        5     17.5  25
# 1    ณิแนน   22     34        1     17.0  22
# 2    จอห์น   25     32        8     16.0  25
# 3      Tim   35     29        8     14.5  35
# 4    Steal   32     27        1     13.5  32

# %%
# ws33
# df.drop('M', axis=1, inplace=True)

cols = ['M','Midterm']
df.drop(cols, axis=1, inplace=True)
df.head()
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        5
# 1    ณิแนน   22     34        1
# 2    จอห์น   25     32        8
# 3      Tim   35     29        8
# 4    Steal   32     27        1

# %%
# ws34 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)

# cols = {'Age':'Math'}
cols = {'Age':'Math',
        'Score':'Bio'}

# df.rename(columns=cols)
df.rename(columns=cols, inplace=True)
df.head()
# Out:
#       Name  Math  Bio  Section
# 0  Kobkiat    25   35        1
# 1    ณิแนน    22   26        1
# 2    จอห์น    25   32        2
# 3      Tim    35   29        2
# 4    Steal    32   27        1

# %%
# ws 35 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri, index_col='Name')

datas = [['KSB',25,35,1],['NiNuan',22,26.0,2]]
cols = ['Name','Age','Score','Section']

newdf = pd.DataFrame(datas, columns=cols)
newdf.set_index('Name', inplace=True)
newdf
df = df.append(newdf)
df
# Out:
# /var/folders/nt/y478_5bn7kj0bmws4pxr4dq40000gn/T/ipykernel_23028/2711028384.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(newdf)
#          Age  Score  Section
# Name
# Kobkiat   25   35.0        1
# ณิแนน     22   26.0        1
# จอห์น     25   32.0        2
# Tim       35   29.0        2
# Steal     32   27.0        1
# Mark      28   30.0        2
# แดง       23   35.0        1
# ดำ        26   25.0        2
# ขาว       25   28.0        1
# Bob       28   30.0        2
# KSB       25   35.0        1
# NiNuan    22   26.0        2

# %%
# ws36 
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri)

# rows = 2             # first row is 0
rows = [1,3,5]
df.drop(rows, axis=0, inplace=True)
df
# Out:
#       Name  Age  Score  Section
# 0  Kobkiat   25     35        1
# 2    จอห์น   25     32        2
# 4    Steal   32     27        1
# 6      แดง   23     35        1
# 7       ดำ   26     25        2
# 8      ขาว   25     28        1
# 9      Bob   28     30        2

# %%
# ws36
uri = 'data/score_ageb.xlsx'
df = pd.read_excel(uri, index_col='Name')
# rows = ['Tim','KSB']
rows = 'Kobkiat'
# rows = ['Bob','KSB']
df.drop(rows, axis=0, inplace=True)
df
# Out:
#        Age  Score  Section
# Name
# ณิแนน   22     26        1
# จอห์น   25     32        2
# Tim     35     29        2
# Steal   32     27        1
# Mark    28     30        2
# แดง     23     35        1
# ดำ      26     25        2
# ขาว     25     28        1
# Bob     28     30        2

# %%
# ws37 
# %matplotlib inline
uri = 'data/score_ageb.csv'
df = pd.read_csv(uri)
df.plot.bar()
df[['Score','Age']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# ws38 
uri = 'data/score_ageb_forSum.csv'
df = pd.read_csv(uri)
df.head()
# Out:
#       Name  Sales1  Sales2  Section
# 0  Kobkiat      25      35        1
# 1    ณิแนน      22      26        1
# 2    จอห์น      25      32        2
# 3      Tim      35      29        2
# 4    Steal      32      27        1

# %%
# ws38 
df.sum()  # or  df.sum(axis=0)
# Out:
# Name       Kobkiatณิแนนจอห์นTimStealMarkแดงดำขาวBob
# Sales1                                          269
# Sales2                                          297
# Section                                          15
# dtype: object

# %%
df.sum(axis=1)
# Out:
# /var/folders/nt/y478_5bn7kj0bmws4pxr4dq40000gn/T/ipykernel_23028/1459321664.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis=1)
# 0    61
# 1    49
# 2    59
# 3    66
# 4    60
# 5    60
# 6    59
# 7    53
# 8    54
# 9    60
# dtype: int64

# %%
cols = ['Sales1','Sales2']
df[cols].sum()
# df[cols].sum(axis=1)
# Out:
# Sales1    269
# Sales2    297
# dtype: int64

# %%
df.groupby(['Section']).sum()
# Out:
#          Sales1  Sales2
# Section
# 1           127     151
# 2           142     146

# %%
cols = ['Sales1','Section']
df[cols].groupby(['Section']).sum()

# cols = ['Sales1', 'Sales2','Name']
# df[cols].groupby(['Name']).sum()
# Out:
#          Sales1
# Section
# 1           127
# 2           142

# %%
# ws39 panda cut see below

# %%
import numpy as np
df = pd.DataFrame({'age': np.random.randint(12, 51, 20)})

groups = [12,19,30,50]
labels = ['teen','young','old']
df['stages'] = pd.cut(df['age'], bins=groups, labels=labels)
df
# Out:
#     age stages
# 0    46    old
# 1    37    old
# 2    25  young
# 3    38    old
# 4    13   teen
# 5    39    old
# 6    24  young
# 7    25  young
# 8    15   teen
# 9    34    old
# 10   34    old
# 11   24  young
# 12   25  young
# 13   33    old
# 14   13   teen
# 15   43    old
# 16   34    old
# 17   31    old
# 18   25  young
# 19   47    old

# %%
df.groupby('stages').count()
# Out:
#         age
# stages
# teen      3
# young     6
# old      11
